# %% [markdown]
# # FAVORITE VACATION LOCATIONS

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Just Like the Griswald's we all want a vacation at some point in the year....

# %% [markdown]
# ### The following dataset will show the most popular vacation locations in the United States from the east coast to the west coast. It will also show how many tourist visit each area during the year.
#
# The Website below is a great reference point to find activities to do while visiting the top vacation locations in the United States:
#
# https://www.getyourguide.com/country-l168990/day-trips-tc172?p=3&sort=popularity&order&searchContext=TRIP_ITEM_GROUP&collectionId=172&tcId=172

# %% [markdown]
# # Exploration of Data

# %%
# import libraries and use csv data file to explore data
import pandas as pd
import numpy as np
import pathlib

Vacation_df = pd.read_csv('touristdata.csv')
Vacation_df.columns
# Out:
# Index(['Place', 'Location', 'Visitors (millions)', 'Total Cost'], dtype='object')

# %%
Vacation_df.shape
# Out:
# (26, 4)

# %%
# Used info to see null columns and to view data within each column
Vacation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Place                26 non-null     object
#  1   Location             26 non-null     object
#  2   Visitors (millions)  26 non-null     float64
#  3   Total Cost           26 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 960.0+ bytes

# %%
# Use sum sort_values to find data and sort into columns
Vacation_df.isnull().sum().sort_values(ascending=False)
# Out:
# Place                  0
# Location               0
# Visitors (millions)    0
# Total Cost             0
# dtype: int64

# %% [markdown]
# ### What were the top 5 places to visit?

# %%
# Pull the top 5 values to reference top places
Vacation_df.head()
# Out:
#                               Place                Location  \
# 0          Walt Disney World Resort        Orlando, Florida
# 1                   Mall of America  Bloomington, Minnesota
# 2                      Times Square      New York, New York
# 3                   Las Vegas Strip       Las Vegas, Nevada
# 4  National Mall and Memorial Parks        Washington, D.C.
#
#    Visitors (millions) Total Cost
# 0                 45.0    $6,320
# 1                 40.0    $1,000
# 2                 35.0      $538
# 3                 31.0    $5,000
# 4                 24.0    $3,000

# %%
# Use df to pull whole dataframe out to look closer at all columns
Vacation_df
# Out:
#                                           Place  \
# 0                      Walt Disney World Resort
# 1                               Mall of America
# 2                                  Times Square
# 3                               Las Vegas Strip
# 4              National Mall and Memorial Parks
# 5                             Disneyland Resort
# 6                      Faneuil Hall Marketplace
# 7            Fisherman's Wharf/Golden Gate Area
# 8                                 Niagara Falls
# 9           Great Smoky Mountains National Park
# 10                                    Navy Pier
# 11           Lake Mead National Recreation Area
# 12                                  Empire Mall
# 13                     Universal Orlando Resort
# 14                             SeaWorld Orlando
# 15                       San Antonio River Walk
# 16                             Salt Lake Temple
# 17  Delaware Water Gap National Recreation Area
# ...

# %% [markdown]
# # Clean Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib

# %%
def get_data(size = 15):
  df = pd.DataFrame()
  df['Place'] = np.random.choice(['Walt Disney World Resort', 'Mall of America', 'Time Square', 
                                  'Las Vegas Strip','National Mall and Memorial Parks', 'Disneyland Resort',], 
                                  size)
  df['Locations'] = np.random.randint(0,100,size)
  df['Visitors_millions'] = np.random.randint(0,100,size)
  return df

# %%
get_data().to_csv('get_data.csv')
df = pd.read_csv('get_data.csv')
df
# Out:
#     Unnamed: 0                             Place  Locations  Visitors_millions
# 0            0  National Mall and Memorial Parks         84                 24
# 1            1                   Las Vegas Strip         54                 42
# 2            2                   Las Vegas Strip         59                 15
# 3            3          Walt Disney World Resort         65                 13
# 4            4                   Las Vegas Strip         95                 16
# 5            5                   Mall of America         32                 49
# 6            6  National Mall and Memorial Parks         46                 54
# 7            7                   Mall of America         96                 99
# 8            8                   Las Vegas Strip         31                 75
# 9            9                   Mall of America         65                 21
# 10          10  National Mall and Memorial Parks         96                  5
# ...

# %%
del df['Unnamed: 0']
df
# Out:
#                                Place  Locations  Visitors_millions
# 0   National Mall and Memorial Parks         84                 24
# 1                    Las Vegas Strip         54                 42
# 2                    Las Vegas Strip         59                 15
# 3           Walt Disney World Resort         65                 13
# 4                    Las Vegas Strip         95                 16
# 5                    Mall of America         32                 49
# 6   National Mall and Memorial Parks         46                 54
# 7                    Mall of America         96                 99
# 8                    Las Vegas Strip         31                 75
# 9                    Mall of America         65                 21
# 10  National Mall and Memorial Parks         96                  5
# 11          Walt Disney World Resort         62                 81
# 12                   Mall of America         51                 52
# ...

# %% [markdown]
# # Analysis of Data

# %% [markdown]
# ### Which vacation location had the most visitors and the least visitors?

# %%
Vacation_df.plot(title = 'Favorite-Vacation-Locations', x = 'Place', xlabel = "Location", rot = 90)
# Out:
# <Axes: title={'center': 'Favorite-Vacation-Locations'}, xlabel='Location'>

# %%
# Plot a bar graph to show location to visitor ratio.
Vacation_df.plot.bar(title = "Favorite-Vacation-Locations", x = "Place", xlabel = "Locations", rot = 90, ylabel = "Vistiors(millions)")
# Out:
# <Axes: title={'center': 'Favorite-Vacation-Locations'}, xlabel='Locations', ylabel='Vistiors(millions)'>

# %% [markdown]
# ### What is the visual percentage difference of the top 6 places to visit on Vacation?

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as pd

# Creating dataset
Place = ['Walt Disney World Resort', 'Mall of America', 'Time Square', 'Las Vegas Strip','National Mall and Memorial Parks', 'Disneyland Resort',]
 
Visitors_millions = [45,40,35,31,24,22.10]

# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(Visitors_millions, labels = Place, autopct='%1.0f%%')

# show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
