# %% [markdown]
# # FAVORITE VACATION LOCATIONS

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Just Like the Griswald's we all want a vacation at some point in the year....

# %% [markdown]
# ### The following dataset will show the most popular vacation locations in the United States from the east coast to the west coast. It will also show how many tourist visit each area during the year.
#
# The Website below is a great reference point to find activities to do while visiting the top vacation locations in the United States:
#
# https://www.getyourguide.com/country-l168990/day-trips-tc172?p=3&sort=popularity&order&searchContext=TRIP_ITEM_GROUP&collectionId=172&tcId=172

# %% [markdown]
# # Exploration of Data

# %%
import pandas as pd

Vacation_df = pd.read_csv('list_top_tourist_attractions_inus-1515j.csv')
Vacation_df.columns
# Out:
# Index(['Place', 'Location', 'Visitors (millions)'], dtype='object')

# %%
Vacation_df.shape
# Out:
# (29, 3)

# %%
Vacation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Place                26 non-null     object
#  1   Location             26 non-null     object
#  2   Visitors (millions)  26 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 824.0+ bytes

# %%
Vacation_df.isnull().sum().sort_values(ascending=False)
# Out:
# Place                  3
# Location               3
# Visitors (millions)    3
# dtype: int64

# %%
Vacation_df.head()
# Out:
#                               Place                Location  \
# 0          Walt Disney World Resort        Orlando, Florida
# 1                   Mall of America  Bloomington, Minnesota
# 2                      Times Square      New York, New York
# 3                   Las Vegas Strip       Las Vegas, Nevada
# 4  National Mall and Memorial Parks        Washington, D.C.
#
#    Visitors (millions)
# 0                 45.0
# 1                 40.0
# 2                 35.0
# 3                 31.0
# 4                 24.0

# %%
Vacation_df
# Out:
#                                           Place  \
# 0                      Walt Disney World Resort
# 1                               Mall of America
# 2                                  Times Square
# 3                               Las Vegas Strip
# 4              National Mall and Memorial Parks
# 5                             Disneyland Resort
# 6                      Faneuil Hall Marketplace
# 7            Fisherman's Wharf/Golden Gate Area
# 8                                 Niagara Falls
# 9           Great Smoky Mountains National Park
# 10                                    Navy Pier
# 11           Lake Mead National Recreation Area
# 12                                  Empire Mall
# 13                     Universal Orlando Resort
# 14                             SeaWorld Orlando
# 15                       San Antonio River Walk
# 16                             Salt Lake Temple
# 17  Delaware Water Gap National Recreation Area
# 18                  Universal Studios Hollywood
# 19                   Metropolitan Museum of Art
# 20                                Waikiki Beach
# 21                                 Grand Canyon
# 22                      Busch Gardens Tampa Bay
# 23                   Cape Cod National Seashore
# 24                           SeaWorld San Diego
# 25           American Museum of Natural History
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
#
#                             Location  Visitors (millions)
# 0                   Orlando, Florida                45.00
# 1             Bloomington, Minnesota                40.00
# 2                 New York, New York                35.00
# 3                  Las Vegas, Nevada                31.00
# 4                   Washington, D.C.                24.00
# 5                Anaheim, California                22.10
# 6              Boston, Massachusetts                20.00
# 7          San Francisco, California                14.00
# 8                           New York                12.00
# 9       North Carolina and Tennessee                 9.40
# 10                 Chicago, Illinois                 8.60
# 11                 Las Vegas, Nevada                 7.60
# 12         Sioux Falls, South Dakota                 7.00
# 13                  Orlando, Florida                 6.20
# 14                  Orlando, Florida                 6.00
# 15                San Antonio, Texas                 5.10
# 16              Salt Lake City, Utah                 5.00
# 17       New Jersey and Pennsylvania                 4.80
# 18        Universal City, California                 4.70
# 19               New York City, N.Y.                 4.50
# 20                  Honolulu, Hawaii                 4.50
# 21                           Arizona                 4.41
# 22                    Tampa, Florida                 4.40
# 23  Barnstable County, Massachusetts                 4.35
# 24             San Diego, California                 4.26
# 25          Manhattan, New York City                 4.00
# 26                               NaN                  NaN
# 27                               NaN                  NaN
# 28                               NaN                  NaN

# %% [markdown]
# # Analysis of Data

# %%
import matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
def get_data(size = 15):
  df = pd.DataFrame()
  df['Place'] = np.random.choice(['Walt Disney World Resort', 'Mall of America', 'Time Square', 'Las Vegas Strip', 'National Mall and Memorial Parks', 'Disneyland Resort', ], size)
  df['Location'] = np.random.randint(0, 100, size)
  df['Visitors_millions'] = np.random.randint(0, 100, size)
  return df

# %%
get_data().to_csv('get_data.csv')
df = pd.read_csv('get_data.csv')
df
# Out:
#     Unnamed: 0                             Place  Location  Visitors_millions
# 0            0                       Time Square        69                 89
# 1            1                 Disneyland Resort         7                 16
# 2            2          Walt Disney World Resort        12                 26
# 3            3                       Time Square         5                 57
# 4            4                 Disneyland Resort        68                 11
# 5            5                 Disneyland Resort        67                 71
# 6            6  National Mall and Memorial Parks         2                 37
# 7            7                       Time Square        84                 77
# 8            8          Walt Disney World Resort        83                  2
# 9            9                   Mall of America        91                 53
# 10          10                 Disneyland Resort        50                 23
# 11          11  National Mall and Memorial Parks        95                 78
# 12          12                   Mall of America        55                  7
# 13          13  National Mall and Memorial Parks        14                 20
# 14          14                 Disneyland Resort        90                 17

# %%
del df['Unnamed: 0']
df
# Out:
#                                Place  Location  Visitors_millions
# 0           Walt Disney World Resort        64                 97
# 1                        Time Square        26                 19
# 2                        Time Square        37                 97
# 3                    Las Vegas Strip        16                 44
# 4                    Mall of America        57                 98
# 5                        Time Square        18                  2
# 6   National Mall and Memorial Parks        85                 98
# 7                    Mall of America        12                  4
# 8   National Mall and Memorial Parks         0                 89
# 9                        Time Square        66                  2
# 10                       Time Square        50                 85
# 11                 Disneyland Resort        25                  5
# 12                       Time Square        42                 10
# 13                 Disneyland Resort        23                 10
# 14                   Mall of America        75                 38

# %%
Vacation_df.plot(title = 'Favorite-Vacation-Locations', x = 'Place', xlabel = "Location", rot = 85, ylabel = "Visitors_million")
# Out:
# <Axes: title={'center': 'Favorite-Vacation-Locations'}, xlabel='Location', ylabel='Visitors_million'>

# %%
# Plot a bar graph to show location to visitor ratio.
Vacation_df.plot.bar(title = "Favorite-Vacation-Locations", x = "Place", xlabel = "Locations", rot = 90, ylabel = "Visitors_million")
# Out:
# <Axes: title={'center': 'Favorite-Vacation-Locations'}, xlabel='Locations', ylabel='Visitors_million'>

# %%
# Plot a pie chart to show the first 14 Places differences.
df["Location"].plot.pie()
# Out:
# <Axes: ylabel='Location'>
