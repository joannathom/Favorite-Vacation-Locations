# %% [markdown]
# # Favorite Vacation Locations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The following dataset will show the most popular vacation locations in the United States from the east coast to the west coast.

# %% [markdown]
# # Exploration of Data

# %%
import pandas as pd

Vacation_df = pd.read_csv('list_top_tourist_attractions_inus-1515j.csv')
Vacation_df.columns
# Out:
# Index(['Place', 'Location', 'Visitors (millions)'], dtype='object')

# %%
Vacation_df.shape
# Out:
# (29, 3)

# %%
Vacation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Place                26 non-null     object
#  1   Location             26 non-null     object
#  2   Visitors (millions)  26 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 824.0+ bytes

# %%
Vacation_df.isnull().sum().sort_values(ascending=False)
# Out:
# Place                  3
# Location               3
# Visitors (millions)    3
# dtype: int64

# %%
Vacation_df.head()
# Out:
#                               Place                Location  \
# 0          Walt Disney World Resort        Orlando, Florida
# 1                   Mall of America  Bloomington, Minnesota
# 2                      Times Square      New York, New York
# 3                   Las Vegas Strip       Las Vegas, Nevada
# 4  National Mall and Memorial Parks        Washington, D.C.
#
#    Visitors (millions)
# 0                 45.0
# 1                 40.0
# 2                 35.0
# 3                 31.0
# 4                 24.0

# %%
Vacation_df
# Out:
#                                           Place  \
# 0                      Walt Disney World Resort
# 1                               Mall of America
# 2                                  Times Square
# 3                               Las Vegas Strip
# 4              National Mall and Memorial Parks
# 5                             Disneyland Resort
# 6                      Faneuil Hall Marketplace
# 7            Fisherman's Wharf/Golden Gate Area
# 8                                 Niagara Falls
# 9           Great Smoky Mountains National Park
# 10                                    Navy Pier
# 11           Lake Mead National Recreation Area
# 12                                  Empire Mall
# 13                     Universal Orlando Resort
# 14                             SeaWorld Orlando
# 15                       San Antonio River Walk
# 16                             Salt Lake Temple
# 17  Delaware Water Gap National Recreation Area
# ...

# %% [markdown]
# # Analysis of Data

# %%
import matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
def get_data(size = 15):
  df = pd.DataFrame()
  df['Place'] = np.random.choice(['Walt Disney World Resort', 'Mall of America', 'Time Square', 'Las Vegas Strip', 'National Mall and Memorial Parks', 'Disneyland Resort'], size)
  df['Location'] = np.random.randint(0, 100, size)
  df['Visitors_millions'] = np.random.randint(0, 100, size)
  return df

# %%
get_data().to_csv('get_data.csv')
df = pd.read_csv('get_data.csv')
df
# Out:
#     Unnamed: 0                             Place  Location  Visitors_millions
# 0            0                 Disneyland Resort        57                 91
# 1            1                       Time Square        99                 40
# 2            2                       Time Square        94                 26
# 3            3                 Disneyland Resort        85                 21
# 4            4                   Mall of America        12                 28
# 5            5                   Mall of America        60                 89
# 6            6                       Time Square        96                 61
# 7            7                 Disneyland Resort        79                 69
# 8            8  National Mall and Memorial Parks         3                 83
# 9            9  National Mall and Memorial Parks         5                 45
# 10          10  National Mall and Memorial Parks        65                 67
# ...

# %%
del df['Unnamed: 0']
df
# Out:
#                                Place  Location  Visitors_millions
# 0                  Disneyland Resort        57                 91
# 1                        Time Square        99                 40
# 2                        Time Square        94                 26
# 3                  Disneyland Resort        85                 21
# 4                    Mall of America        12                 28
# 5                    Mall of America        60                 89
# 6                        Time Square        96                 61
# 7                  Disneyland Resort        79                 69
# 8   National Mall and Memorial Parks         3                 83
# 9   National Mall and Memorial Parks         5                 45
# 10  National Mall and Memorial Parks        65                 67
# 11          Walt Disney World Resort        33                 39
# 12          Walt Disney World Resort        63                 17
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot.bar(title = 'Favorite-Vacation-Locations')
# Out:
# <Axes: title={'center': 'Favorite-Vacation-Locations'}>

# %%
df['Location'].plot.pie()
# Out:
# <Axes: ylabel='Location'>
